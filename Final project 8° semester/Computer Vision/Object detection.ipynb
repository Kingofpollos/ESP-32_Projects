# %%
import cv2 #Import opencv
import time

# %%
#test open cv
# img = cv2.imread('lena.PNG')
# cv2.imshow('xd',img)
# cv2.waitKey(0)

# %%
thres = 0.45
# cap = cv2.VideoCapture(0)
cap = cv2.VideoCapture('http://192.168.1.185:8080/videofeed') #http://192.168.1.185:8080/videofeed
cap.set(3,1280)
cap.set(4,720)
cap.set(10,70)
# Out:
# False

# %%
#Import label names
classNames = []
classFile = 'coco.names'
with open(classFile,'rt') as f:
    classNames = f.read().rstrip('\n').split('\n')
# print(len(classNames))

# %%
#Set configuration
configPath = "ssd_mobilenet_v3_large_coco_2020_01_14.pbtxt"
weightsPath = "frozen_inference_graph.pb"

# %%
#Load the neural network
net = cv2.dnn_DetectionModel(weightsPath,configPath)
net.setInputSize(320,320).setInputScale(1.0/ 127.5).setInputMean((127.5, 127.5, 127.5)).setInputSwapRB(True)
# Out:
# <dnn_Model 000001D3437E5890>

# %%
while True:
    t_start = time.time()#process_time()
    left = []
    center = []
    right = []
    success,img = cap.read()
    cv2.line(img, (240,0), (240,480), color=(100,100,0), thickness=1)
    cv2.line(img, (480,0), (480,480), color=(100,100,0), thickness=1)
    classIds, confs, bbox = net.detect(img,confThreshold=thres)
#     print('Class id: {}\n Bbox: {}'.format(classIds,bbox))
    if len(classIds) != 0:
        for classId, confidence,box in zip(classIds.flatten(),confs.flatten(),bbox):
            cv2.rectangle(img,box,color=(0,255,0),thickness=1)
            cv2.putText(img,(classNames[classId-1].upper()+' '+str(round(confidence*100,2))),(box[0]+10,box[1]+30),
                        cv2.FONT_HERSHEY_COMPLEX,1,(255,100,0),2)
            if (box[0]<240):
                left.append(box[0])
            elif (240<=box[0]<480):
                center.append(box[0])
            else:
                right.append(box[0])
#             print('--Objects in left: {} \n Objects in center: {} \n Objects in right: {}'.format(len(left),len(center),len(right)))
    if img is not None:
        cv2.imshow("Output",img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    t_end = time.time()#process_time()
    print('{} FPS'.format(round(1/(t_end-t_start))))
    cv2.putText(img,'{}'.format(round(1/(t_end-t_start))), (610,320),cv2.FONT_HERSHEY_COMPLEX,1,(255,100,0),1)
cap.release()

cv2.destroyAllWindows()
# Out:
# 8 FPS
# 15 FPS
# 17 FPS
# 17 FPS
# 16 FPS
# 17 FPS
# 18 FPS
# 17 FPS
# 18 FPS
# 21 FPS
# 17 FPS
# 18 FPS
# 17 FPS
# 16 FPS
# 17 FPS
# 17 FPS
# 18 FPS
# 17 FPS
# 17 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 21 FPS
# 20 FPS
# 21 FPS
# 21 FPS
# 20 FPS
# 20 FPS
# 21 FPS
# 20 FPS
# 21 FPS
# 19 FPS
# 21 FPS
# 22 FPS
# 21 FPS
# 20 FPS
# 21 FPS
# 21 FPS
# 20 FPS
# 20 FPS
# 20 FPS
# 21 FPS
# 21 FPS
# 20 FPS
# 19 FPS
# 18 FPS
# 17 FPS
# 17 FPS
# 18 FPS
# 18 FPS
# 19 FPS
# 19 FPS
# 21 FPS
# 21 FPS
# 21 FPS
# 20 FPS
# 22 FPS
# 21 FPS
# 21 FPS
# 20 FPS
# 22 FPS
# 22 FPS
# 22 FPS
# 20 FPS
# 21 FPS
# 21 FPS
# 20 FPS
# 20 FPS
# 21 FPS
# 22 FPS
# 21 FPS
# 20 FPS
# 21 FPS
# 21 FPS
# 20 FPS
# 20 FPS
# 20 FPS
# 21 FPS
# 21 FPS
# 20 FPS
# 21 FPS
# 21 FPS
# 22 FPS
# 20 FPS
# 21 FPS
# 21 FPS
# 21 FPS
# 20 FPS
# 22 FPS
# 21 FPS
# 22 FPS
# 20 FPS
# 21 FPS
# 20 FPS
# 21 FPS
# 20 FPS
# 21 FPS
# 20 FPS
# 21 FPS
# 20 FPS
# 21 FPS
# 21 FPS
# 21 FPS
# 20 FPS
# 21 FPS
# 17 FPS
# 17 FPS
# 19 FPS
# 20 FPS
# 21 FPS
# 20 FPS
# 18 FPS
# 18 FPS
# 17 FPS
# 17 FPS
# 17 FPS
# 23 FPS
# 21 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 17 FPS
# 17 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 20 FPS
# 18 FPS
# 16 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 17 FPS
# 17 FPS
# 18 FPS
# 18 FPS
# 17 FPS
# 18 FPS
# 18 FPS
# 19 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 17 FPS
# 16 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 17 FPS
# 18 FPS
# 18 FPS
# 19 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 17 FPS
# 17 FPS
# 17 FPS
# 18 FPS
# 17 FPS
# 17 FPS
# 16 FPS
# 17 FPS
# 16 FPS
# 16 FPS
# 16 FPS
# 16 FPS
# 17 FPS
# 17 FPS
# 17 FPS
# 17 FPS
# 16 FPS
# 17 FPS
# 17 FPS
# 18 FPS
# 18 FPS
# 20 FPS
# 21 FPS
# 22 FPS
# 20 FPS
# 21 FPS
# 19 FPS
# 20 FPS
# 18 FPS
# 20 FPS
# 20 FPS
# 20 FPS
# 21 FPS
# 21 FPS
# 20 FPS
# 21 FPS
# 20 FPS
# 21 FPS
# 20 FPS
# 21 FPS
# 21 FPS
# 20 FPS
# 16 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 20 FPS
# 21 FPS
# 20 FPS
# 21 FPS
# 22 FPS
# 20 FPS
# 20 FPS
# 20 FPS
# 21 FPS
# 20 FPS
# 20 FPS
# 20 FPS
# 18 FPS
# 18 FPS
# 16 FPS
# 16 FPS
# 17 FPS
# 17 FPS
# 18 FPS
# 18 FPS
# 18 FPS
# 20 FPS
# 19 FPS
# 20 FPS
# 17 FPS
# 21 FPS
# 20 FPS
# 22 FPS
# 19 FPS
# 19 FPS
# 21 FPS
# 22 FPS
# 21 FPS
# 20 FPS

# %%
# cv2.destroyAllWindows()

# %%
classNames = []
classFile = 'coco.names'
with open(classFile,'rt') as f:
    classNames = f.read().rstrip('\n').split('\n')
print(classNames[0])
# Out:
# person iwi
